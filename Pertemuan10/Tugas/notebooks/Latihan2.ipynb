# %% [markdown]
# # Buat Dataset

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# Buat dataset dari tabel
data = {
    "Nim": [
        "TI001", "TI002", "TI003", "TI004", "TI005",
        "TI006", "TI007", "TI008", "TI009", "TI010"
    ],
    "Hasil Sebenarnya": [
        "Lulus", "Lulus", "Lulus", "Lulus", "Lulus",
        "Tidak Lulus", "Tidak Lulus", "Tidak Lulus", "Tidak Lulus", "Tidak Lulus"
    ],
    "Prediksi": [
        "Lulus", "Lulus", "Lulus", "Tidak Lulus", "Tidak Lulus",
        "Lulus", "Tidak Lulus", "Tidak Lulus", "Tidak Lulus", "Tidak Lulus"
    ]
}

df = pd.DataFrame(data)

print("Data Kelulusan MataKuliah AI")
display(df)
# Out:
# Data Kelulusan MataKuliah AI
#      Nim Hasil Sebenarnya     Prediksi
# 0  TI001            Lulus        Lulus
# 1  TI002            Lulus        Lulus
# 2  TI003            Lulus        Lulus
# 3  TI004            Lulus  Tidak Lulus
# 4  TI005            Lulus  Tidak Lulus
# 5  TI006      Tidak Lulus        Lulus
# 6  TI007      Tidak Lulus  Tidak Lulus
# 7  TI008      Tidak Lulus  Tidak Lulus
# 8  TI009      Tidak Lulus  Tidak Lulus
# 9  TI010      Tidak Lulus  Tidak Lulus

# %% [markdown]
# # Menghitung TP, FP, FN, TN

# %%
# Positif  = "Lulus"
# Negatif  = "Tidak Lulus"

TP = ((df["Hasil Sebenarnya"] == "Lulus") & (df["Prediksi"] == "Lulus")).sum()
FN = ((df["Hasil Sebenarnya"] == "Lulus") & (df["Prediksi"] == "Tidak Lulus")).sum()
FP = ((df["Hasil Sebenarnya"] == "Tidak Lulus") & (df["Prediksi"] == "Lulus")).sum()
TN = ((df["Hasil Sebenarnya"] == "Tidak Lulus") & (df["Prediksi"] == "Tidak Lulus")).sum()

print("\n=== PERHITUNGAN MANUAL TP, FP, FN, TN ===")
print("TP =", TP)
print("FN =", FN)
print("FP =", FP)
print("TN =", TN)
# Out:
# === PERHITUNGAN MANUAL TP, FP, FN, TN ===
# TP = 3
# FN = 2
# FP = 1
# TN = 4

# %% [markdown]
# # Menghitung Accuracy, Precision, Recall

# %% [markdown]
# Menghitung Accuracy, Precision, Recall menggunakan RUMUS

# %%
# Rumus:
Accuracy_manual  = (TP + TN) / (TP + TN + FP + FN)
Precision_manual = TP / (TP + FP)
Recall_manual    = TP / (TP + FN)

print("\n=== HASIL PERHITUNGAN MENGGUNAKAN RUMUS ===")
print("Accuracy  :", Accuracy_manual)
print("Precision :", Precision_manual)
print("Recall    :", Recall_manual)
# Out:
# === HASIL PERHITUNGAN MENGGUNAKAN RUMUS ===
# Accuracy  : 0.7
# Precision : 0.75
# Recall    : 0.6

# %% [markdown]
# Menghitung Accuracy, Precision, Recall menggunakan sklearn

# %%
labels = ["Lulus", "Tidak Lulus"]
cm = confusion_matrix(df["Hasil Sebenarnya"], df["Prediksi"], labels=labels)

Accuracy_sklearn  = accuracy_score(df["Hasil Sebenarnya"], df["Prediksi"])
Precision_sklearn = precision_score(df["Hasil Sebenarnya"], df["Prediksi"], pos_label="Lulus")
Recall_sklearn    = recall_score(df["Hasil Sebenarnya"], df["Prediksi"], pos_label="Lulus")

print("\n=== CONFUSION MATRIX (sklearn) ===")
print(cm)

print("\n=== HASIL PERHITUNGAN MENGGUNAKAN sklearn ===")
print("Accuracy  :", Accuracy_sklearn)
print("Precision :", Precision_sklearn)
print("Recall    :", Recall_sklearn)
# Out:
# === CONFUSION MATRIX (sklearn) ===
# [[3 2]
#  [1 4]]
#
# === HASIL PERHITUNGAN MENGGUNAKAN sklearn ===
# Accuracy  : 0.7
# Precision : 0.75
# Recall    : 0.6
